# %%
# %cd "C:\Users\asmaa\Desktop\Amr\Master's Thesis v0.4"
# Out:
# C:\Users\asmaa\Desktop\Amr\Master's Thesis v0.4
# C:\Users\asmaa\PycharmProjects\pythonProject\.venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import torch

# %%
# parameters
lambd = 1.55
# wave number and normalized spacing
k_0 = 2 * np.pi / lambd

# %%
save_folder_path = r"C:\Users\asmaa\Desktop\Amr\2nd Paper\Experiments\TM"

# %%
EIs_analytic_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Fields and EIs\analytic_EIs.npy")
EIs_FD_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FD.npy")
EIs_DCNN_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_DCNN.npy")
EIs_FCNN_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FCNN.npy")

errors_FD_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\modes_errors_FD.npy")
errors_DCNN_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\modes_errors_DCNN.npy")
errors_FCNN_1_TM = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\modes_errors_FCNN.npy")


EIs_analytic_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Fields and EIs\analytic_EIs.npy")
EIs_FD_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FD.npy")
EIs_DCNN_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_DCNN.npy")
EIs_FCNN_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FCNN.npy")

errors_FD_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\modes_errors_FD.npy")
errors_DCNN_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\modes_errors_DCNN.npy")
errors_FCNN_2_TM = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\modes_errors_FCNN.npy")

EIs_analytic_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Fields and EIs\analytic_EIs.npy")
EIs_FD_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FD.npy")
EIs_DCNN_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_DCNN.npy")
EIs_FCNN_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FCNN.npy")

errors_FD_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\modes_errors_FD.npy")
errors_DCNN_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\modes_errors_DCNN.npy")
errors_FCNN_3_TM = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\modes_errors_FCNN.npy")

# %%
# EIs_analytic_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Fields and EIs\analytic_EIs.npy")
# EIs_FD_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FD.npy")
# EIs_DCNN_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_DCNN.npy")
# EIs_FCNN_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FCNN.npy")
# 
# errors_FD_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\modes_errors_FD.npy")
# errors_DCNN_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\modes_errors_DCNN.npy")
# errors_FCNN_1_TE = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\modes_errors_FCNN.npy")
# 
# 
# EIs_analytic_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Fields and EIs\analytic_EIs.npy")
# EIs_FD_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FD.npy")
# EIs_DCNN_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_DCNN.npy")
# EIs_FCNN_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FCNN.npy")
# 
# errors_FD_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\modes_errors_FD.npy")
# errors_DCNN_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\modes_errors_DCNN.npy")
# errors_FCNN_2_TE = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\modes_errors_FCNN.npy")
# 
# EIs_analytic_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Fields and EIs\analytic_EIs.npy")
# EIs_FD_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FD.npy")
# EIs_DCNN_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_DCNN.npy")
# EIs_FCNN_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FCNN.npy")
# 
# errors_FD_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\modes_errors_FD.npy")
# errors_DCNN_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\modes_errors_DCNN.npy")
# errors_FCNN_3_TE = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\modes_errors_FCNN.npy")

# %%
font = {
    'weight' : 'bold',
    'size' : 14
    }

matplotlib.rc('font', **font)

# %%
x_ticks = [r'$\lambda/10$', r'$\lambda/20$', r'$\lambda/30$', r'$\lambda/40$', r'$\lambda/50$']

# %%
plt.figure(figsize=(8, 6))
plt.axhline(EIs_analytic_1_TM[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.errorbar(np.arange(len(EIs_FD_1_TM[:5])), EIs_FD_1_TM[:5], label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot', zorder=2)
plt.errorbar(np.arange(len(EIs_FCNN_1_TM)), EIs_FCNN_1_TM.mean(axis=1)[:, 0], label='FCNN', linewidth=3, color='blue', marker='o', markersize=10,  yerr=EIs_FCNN_1_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=1)
plt.errorbar(np.arange(len(EIs_DCNN_1_TM)), EIs_DCNN_1_TM.mean(axis=1)[:, 0], label='DCNN', color='red', linewidth=3, marker='*', markersize=10,  yerr=EIs_DCNN_1_TM.std(axis=1)[:, 0], ecolor='orange', capsize=5, zorder=2)
# plt.xticks([0, 1, 2, 3 ,4], [r'$\lambda$/5', r'$\lambda$/10', r'$\lambda$/15', r'$\lambda$/20', r'$\lambda$/25'])
plt.ylabel('EI')
plt.legend();   
plt.grid()
plt.ylabel('EI')
plt.xlabel('step size')
# plt.ylim([1.5358, 1.53705])
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
x_ticks = [r'$\lambda/10$', r'$\lambda/20$', r'$\lambda/30$', r'$\lambda/40$', r'$\lambda/50$']

# %%
plt.figure(figsize=(8, 6))
plt.errorbar(np.arange(len(errors_FCNN_1_TM)),errors_FCNN_1_TM.mean(axis=1)[:, 0], label='FCNN', linewidth=3, color='blue', marker='o', markersize=10,  yerr=errors_FCNN_1_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=1)
plt.plot(np.arange(len(errors_FD_1_TM[:5])), errors_FD_1_TM[:5], label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot', zorder=2)
plt.errorbar(np.arange(len(errors_DCNN_1_TM)), errors_DCNN_1_TM.mean(axis=1)[:, 0], label='DCNN', color='red', linewidth=3, marker='*', markersize=10,  yerr=errors_DCNN_1_TM.std(axis=1)[:, 0], ecolor='orange', capsize=5, zorder=0)
plt.ylabel('Error(%)')
plt.legend()
plt.grid()
plt.ylim([-0.25, 5])
plt.xlabel('step size')
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))
plt.axhline(EIs_analytic_2_TM[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.errorbar(np.arange(len(EIs_FD_2_TM[:5])), EIs_FD_2_TM[:5], label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot', zorder=2)
plt.errorbar(np.arange(len(EIs_FCNN_2_TM)), EIs_FCNN_2_TM.mean(axis=1)[:, 0], label='FCNN', linewidth=3, color='blue', marker='o', markersize=10,  yerr=EIs_FCNN_2_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=1)
plt.errorbar(np.arange(len(EIs_DCNN_2_TM)), EIs_DCNN_2_TM.mean(axis=1)[:, 0], label='DCNN', color='red', linewidth=3, marker='*', markersize=10,  yerr=EIs_DCNN_2_TM.std(axis=1)[:, 0], ecolor='orange', capsize=5, zorder=2)
# plt.xticks([0, 1, 2, 3 ,4], [r'$\lambda$/5', r'$\lambda$/10', r'$\lambda$/15', r'$\lambda$/20', r'$\lambda$/25'])
plt.ylabel('EI')
plt.legend();   
plt.grid()
plt.ylabel('EI')
plt.xlabel('step size')
plt.ylim([1.682, 1.688])
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))
plt.errorbar(np.arange(len(errors_FCNN_2_TM)),errors_FCNN_2_TM.mean(axis=1)[:, 0], label='FCNN', linewidth=3, color='blue', marker='o', markersize=10,  yerr=errors_FCNN_2_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=1)
plt.plot(np.arange(len(errors_FD_2_TM[:5])), errors_FD_2_TM[:5], label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot', zorder=2)
plt.errorbar(np.arange(len(errors_DCNN_2_TM)), errors_DCNN_2_TM.mean(axis=1)[:, 0], label='DCNN', color='red', linewidth=3, marker='*', markersize=10,  yerr=errors_DCNN_2_TM.std(axis=1)[:, 0], ecolor='orange', capsize=5, zorder=0)
plt.ylabel('Error(%)')
plt.legend()
plt.grid()
plt.ylim([-0.25, 5])
plt.xlabel('step size')
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))
plt.axhline(EIs_analytic_3_TM[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.errorbar(np.arange(len(EIs_FD_3_TM[:5])), EIs_FD_3_TM[:5], label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot', zorder=2)
plt.errorbar(np.arange(len(EIs_FCNN_3_TM)), EIs_FCNN_3_TM.mean(axis=1)[:, 0], label='FCNN', linewidth=3, color='blue', marker='o', markersize=10,  yerr=EIs_FCNN_3_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=1)
plt.errorbar(np.arange(len(EIs_DCNN_3_TM)), EIs_DCNN_3_TM.mean(axis=1)[:, 0], label='DCNN', color='red', linewidth=3, marker='*', markersize=10,  yerr=EIs_DCNN_3_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=3)
# plt.xticks([0, 1, 2, 3 ,4], [r'$\lambda$/5', r'$\lambda$/10', r'$\lambda$/15', r'$\lambda$/20', r'$\lambda$/25'])
plt.ylabel('EI')
plt.legend();   
plt.grid()
plt.ylabel('EI')
plt.xlabel('step size')
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))
plt.errorbar(np.arange(len(EIs_FCNN_3_TM)),errors_FCNN_3_TM.mean(axis=1)[:, 0], label='FCNN', linewidth=3, color='blue', marker='o', markersize=10,  yerr=errors_FCNN_3_TM.std(axis=1)[:, 0], ecolor='green', capsize=5, zorder=1)
plt.plot(np.arange(len(EIs_FD_2_TM[:5])), errors_FD_3_TM[:5], label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot', zorder=2)
plt.errorbar(np.arange(len(EIs_DCNN_2_TM)), errors_DCNN_3_TM.mean(axis=1)[:, 0], label='DCNN', color='red', linewidth=3, marker='*', markersize=10,  yerr=errors_DCNN_3_TM.std(axis=1)[:, 0], ecolor='orange', capsize=5, zorder=0)
plt.ylabel('Error(%)')
plt.legend()
plt.grid()
plt.xlabel('step size')
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %% [markdown]
# # Numerical visualizatoin of the Cloesst convergence graph

# %%
def multiplicative_inverse_function(x, a, b, c):
    """multiplicative inverse function: y = 1/(x/a - b)+ c"""
    return 1/((x**2)/a - b) + c

def fit_curve(x_data, y_data, candidate_fun = multiplicative_inverse_function):
    """
    Fits an exponential function y = a * exp(b * x) + c using SciPy's curve_fit.

    Args:
        x_data (array-like): Input x values.
        y_data (array-like): Corresponding y values.

    Returns:
        a_fit (float): Fitted parameter a.
        b_fit (float): Fitted parameter b.
        c_fit (float): Fitted parameter c.
    """
    y_mean = np.mean(y_data)
    y_std = np.std(y_data)
    y_scaled = (y_data - y_mean) / y_std  # Normalize y for numerical stability

    # Initial parameter guesses
    initial_params = [2, -1, 0.1]

    # Fit the exponential function
    popt, _ = curve_fit(candidate_fun, x_data, y_scaled, p0=initial_params)

    # Extract optimized parameters
    a_fit, b_fit, c_fit = popt

    # Rescale c to original y scale
    # c_fit = c_fit * y_std + y_mean
    # a_fit = a_fit * y_std  # Rescale a accordingly

    return a_fit, b_fit, c_fit

# Example data
x_data = np.delete(np.arange(len(EIs_DCNN_3_TE)), [])
y_data =np.delete(EIs_DCNN_3_TE, [])


# Fit the data
a_fit, b_fit, c_fit = fit_curve(x_data, y_data, multiplicative_inverse_function)
print(f"Fitted parameters: a = {a_fit:.4f}, b = {b_fit:.4f}, c = {c_fit:.4f}")

# Generate fitted curve
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit =multiplicative_inverse_function(x_fit, a_fit, b_fit, c_fit) * np.std(y_data) + np.mean(y_data)

# Plot results
plt.scatter(x_data, y_data, label="Data", color="red")
# plt.plot(x_fit, y_fit, label=f"Fit: {a_fit:.2f} * exp({b_fit:.2f} * x) + {c_fit:.2f}", color="blue")
plt.plot(x_fit, y_fit, label=f"Fit: 1/($x^2$/{a_fit:.2f} - ({b_fit:.2f})) + {c_fit:.2f}", color="blue")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Inverse Fit (SciPy curve_fit)")
plt.show()
# Out:
# Fitted parameters: a = 0.0602, b = -0.3967, c = -0.5210

# %%
multiplicative_inverse_function(4, a_fit, b_fit, c_fit) * np.std(y_data) + np.mean(y_data)
# Out:
# 2.8802664654126278
