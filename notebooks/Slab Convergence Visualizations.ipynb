# %%
from IPython.core.pylabtools import figsize
# %cd "C:\Users\asmaa\Desktop\Amr\Master's Thesis v0.4"
# Out:
# C:\Users\asmaa\Desktop\Amr\Master's Thesis v0.4
# C:\Users\asmaa\PycharmProjects\pythonProject\.venv\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
import torch

# %%
import devices
import utils
import samplers

# %%
save_folder_path = r"C:\Users\asmaa\Desktop\Amr\2nd Paper\Experiments\TE"

# %%
EIs_analytic_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Fields and EIs\analytic_EIs.npy")
EIs_DCNN_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_DCNN.npy")
EIs_FCNN_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FCNN.npy")
EIs_FD_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FD.npy")

EIs_analytic_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Fields and EIs\analytic_EIs.npy")
EIs_DCNN_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_DCNN.npy")
EIs_FCNN_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FCNN.npy")
EIs_FD_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FD.npy")

EIs_analytic_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Fields and EIs\analytic_EIs.npy")
EIs_DCNN_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_DCNN.npy")
EIs_FCNN_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FCNN.npy")
EIs_FD_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FD.npy")
# analytic_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\analytic_fields.npy")
# DCNN_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\DCNN_fields.npy")
# FCNN_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\FCNN_fields.npy")
# FD_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\FD_fields.npy")
EIs_analytic_1.shape, EIs_DCNN_1.shape, EIs_FCNN_1.shape, EIs_FD_1.shape
# Out:
# ((3,), (5, 10, 1), (5, 10, 1), (5, 1))

# %%
x_ticks = [r'$\lambda/10$', r'$\lambda/20$', r'$\lambda/30$', r'$\lambda/40$', r'$\lambda/50$']

# %%
font = {
    'weight' : 'bold',
    'size' : 14
    }

matplotlib.rc('font', **font)

# %%
plt.figure(figsize=(8, 6))
plt.axhline(EIs_analytic_1[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.plot(EIs_DCNN_1, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
plt.plot(EIs_FCNN_1, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
plt.plot(EIs_FD_1, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
plt.legend()
# plt.ylim([1.5365,1.538])
plt.grid()
plt.ylabel('EI')
plt.xlabel('step size')
plt.xticks([0, 1, 2, 3, 4], x_ticks);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 plt.figure(figsize=(8, 6))
#       2 plt.axhline(EIs_analytic_1[0], color='black', linestyle='--', linewidth=3, label='analytic')
# ----> 3 plt.plot(EIs_DCNN_1, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
#       4 plt.plot(EIs_FCNN_1, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
#       5 plt.plot(EIs_FD_1, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
#
# File ~\PycharmProjects\pythonProject\.venv\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
# ...

# %%
plt.figure(figsize=(8, 6))
plt.axhline(EIs_analytic_2[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.plot(EIs_DCNN_2, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
plt.plot(EIs_FCNN_2, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
plt.plot(EIs_FD_2, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
plt.legend()
# plt.ylim([1.5365,1.538])
plt.ylabel('EI')
plt.xlabel('step size')
plt.grid()
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))

plt.axhline(EIs_analytic_3[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.plot(EIs_DCNN_3, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
plt.plot(EIs_FCNN_3, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
plt.plot(EIs_FD_3, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
plt.legend()
# plt.ylim([1.5365,1.538])
plt.ylabel('EI')
plt.xlabel('step size')
plt.grid()
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
save_folder_path = r"C:\Users\asmaa\Desktop\Amr\2nd Paper\Experiments\TM"

# %%
EIs_analytic_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Fields and EIs\analytic_EIs.npy")
EIs_DCNN_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_DCNN.npy")
EIs_FCNN_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FCNN.npy")
EIs_FD_1 = np.load(save_folder_path + r"\Planar\Several Modes Weakly Guiding\Convergence\EIs_FD.npy")

EIs_analytic_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Fields and EIs\analytic_EIs.npy")
EIs_DCNN_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_DCNN.npy")
# EIs_FCNN_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FCNN.npy")
EIs_FD_2 = np.load(save_folder_path + r"\Planar\Several Modes Moderate Contrast\Convergence\EIs_FD.npy")

EIs_analytic_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Fields and EIs\analytic_EIs.npy")
EIs_DCNN_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_DCNN.npy")
# EIs_FCNN_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FCNN.npy")
EIs_FD_3 = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\Convergence\EIs_FD.npy")
# analytic_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\analytic_fields.npy")
# DCNN_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\DCNN_fields.npy")
# FCNN_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\FCNN_fields.npy")
# FD_fields = np.load(save_folder_path + r"\Planar\Several Modes High Contrast\FD_fields.npy")
EIs_analytic_1.shape, EIs_DCNN_1.shape, EIs_FCNN_1.shape, EIs_FD_1.shape
# Out:
# ((3,), (5, 1), (5, 1), (5, 1))

# %%
x_ticks = [r'$\lambda/10$', r'$\lambda/20$', r'$\lambda/30$', r'$\lambda/40$', r'$\lambda/50$']

# %%
font = {
    'weight' : 'bold',
    'size' : 14
    }

matplotlib.rc('font', **font)

# %%
plt.figure(figsize=(8, 6))
plt.axhline(EIs_analytic_1[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.plot(EIs_DCNN_1, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
plt.plot(EIs_FCNN_1, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
plt.plot(EIs_FD_1, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
plt.legend()
# plt.ylim([1.5365,1.538])
plt.ylabel('EI')
plt.xlabel('step size')
plt.grid()
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))

plt.axhline(EIs_analytic_2[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.plot(EIs_DCNN_2, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
# plt.plot(EIs_FCNN_2, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
plt.plot(EIs_FD_2, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
plt.legend()
# plt.ylim([1.5365,1.538])
plt.ylabel('EI')
plt.xlabel('step size')
plt.grid()
plt.xticks([0, 1, 2, 3, 4], x_ticks);

# %%
plt.figure(figsize=(8, 6))

plt.axhline(EIs_analytic_3[0], color='black', linestyle='--', linewidth=3, label='analytic')
plt.plot(EIs_DCNN_3, label='DCNN', color='red', linewidth=3, marker='*', markersize=10)
# plt.plot(EIs_FCNN_3, label='FCNN', linewidth=3, color='blue', marker='o', markersize=10)
plt.plot(EIs_FD_3, label='FD', linewidth=3, color='violet', marker='^', markersize=10, linestyle='dashdot')
plt.legend()
plt.ylabel('EI')
plt.xlabel('step size')
# plt.ylim([1.5365,1.538])
plt.grid()
plt.xticks([0, 1, 2, 3, 4], x_ticks);
